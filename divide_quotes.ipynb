# %%
import pandas as pd

df = pd.read_excel('NLP_Quotes.xlsx')
df = df.sample(frac=1).reset_index(drop=True)
df_bins = pd.qcut(df.index, 4, labels=False)

# %%
df.iloc[df_bins == 0].to_excel("Rashmi.xlsx")
df.iloc[df_bins == 1].to_excel("Rohit.xlsx")
df.iloc[df_bins == 2].to_excel("Vaishnavi.xlsx")
df.iloc[df_bins == 3].to_excel("Varun.xlsx")

# %%
df
# Out:
#                                                Column1  \
# 0             the miserable have no medicine but hope.
# 1    love is that condition in which the happiness ...
# 2    the man who counts on the aid of a god deserve...
# 3    people like to say love is unconditional, but ...
# 4    go on with what your heart tells you, or you w...
# ..                                                 ...
# 389  when my problems seem overwhelming and impossi...
# 390  so, this is my life. and i want you to know th...
# 391  cats are intended to teach us that not everyth...
# 392  although i understand that all days are equal ...
# 393  part of the problem with the word 'disabilitie...
#
#                         Column2        Column3
# 0           william shakespeare           hope
# 1            robert a. heinlein      happiness
# 2    glen cook, dreams of steel            god
# 3                  katja millay      happiness
# 4                  rick riordan  inspirational
# ...
